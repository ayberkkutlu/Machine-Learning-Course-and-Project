# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ayber\OneDrive\Masaüstü\ML\Data\external\Fatigue_data.csv")

# %%
df.head()
# Out:
#    Sl. No.   NT  THT  THt  THQCr  CT   Ct    DT   Dt  QmT  ...      S    Ni  \
# 0        1  885   30    0      0  30  0.0  30.0  0.0   30  ...  0.022  0.01
# 1        2  885   30    0      0  30  0.0  30.0  0.0   30  ...  0.017  0.08
# 2        3  885   30    0      0  30  0.0  30.0  0.0   30  ...  0.015  0.02
# 3        4  885   30    0      0  30  0.0  30.0  0.0   30  ...  0.024  0.01
# 4        5  885   30    0      0  30  0.0  30.0  0.0   30  ...  0.022  0.01
#
#      Cr    Cu   Mo  RedRatio    dA    dB    dC  Fatigue
# 0  0.02  0.01  0.0       825  0.07  0.02  0.04      232
# 1  0.12  0.08  0.0       610  0.11  0.00  0.04      235
# 2  0.03  0.01  0.0      1270  0.07  0.02  0.00      235
# 3  0.02  0.01  0.0      1740  0.06  0.00  0.00      241
# 4  0.02  0.02  0.0       825  0.04  0.02  0.00      225
#
# [5 rows x 27 columns]

# %%
df.dtypes
# Out:
# Sl. No.       int64
# NT            int64
# THT           int64
# THt           int64
# THQCr         int64
# CT            int64
# Ct          float64
# DT          float64
# Dt          float64
# QmT           int64
# TT            int64
# Tt            int64
# TCr         float64
# C           float64
# Si          float64
# Mn          float64
# P           float64
# S           float64
# Ni          float64
# Cr          float64
# Cu          float64
# Mo          float64
# RedRatio      int64
# dA          float64
# dB          float64
# dC          float64
# Fatigue       int64
# dtype: object

# %%
df.NT
# Out:
# 0      885
# 1      885
# 2      885
# 3      885
# 4      885
#       ...
# 432    930
# 433    930
# 434    930
# 435    930
# 436    930
# Name: NT, Length: 437, dtype: int64

# %%
df[['CT','DT']]
# Out:
#       CT       DT
# 0     30   30.000
# 1     30   30.000
# 2     30   30.000
# 3     30   30.000
# 4     30   30.000
# ..   ...      ...
# 432  930  895.812
# 433  930  895.812
# 434  930  895.812
# 435  930  895.812
# 436  930  895.812
#
# [437 rows x 2 columns]

# %%
df['new']=np.random.rand(437)

# %%
df
# Out:
#      Sl. No.   NT  THT  THt  THQCr   CT     Ct       DT    Dt  QmT  ...    Ni  \
# 0          1  885   30    0      0   30    0.0   30.000   0.0   30  ...  0.01
# 1          2  885   30    0      0   30    0.0   30.000   0.0   30  ...  0.08
# 2          3  885   30    0      0   30    0.0   30.000   0.0   30  ...  0.02
# 3          4  885   30    0      0   30    0.0   30.000   0.0   30  ...  0.01
# 4          5  885   30    0      0   30    0.0   30.000   0.0   30  ...  0.01
# ..       ...  ...  ...  ...    ...  ...    ...      ...   ...  ...  ...   ...
# 432      433  930   30    0      0  930  340.2  895.812  70.2  140  ...  0.02
# 433      434  930   30    0      0  930  340.2  895.812  70.2  140  ...  0.07
# 434      435  930   30    0      0  930  340.2  895.812  70.2   60  ...  0.06
# 435      436  930   30    0      0  930  340.2  895.812  70.2   60  ...  0.02
# 436      437  930   30    0      0  930  340.2  895.812  70.2   60  ...  0.07
#
# ...

# %%
del df['new']

# %%
df
# Out:
#      Sl. No.   NT  THT  THt  THQCr   CT     Ct       DT    Dt  QmT  ...  \
# 0          1  885   30    0      0   30    0.0   30.000   0.0   30  ...
# 1          2  885   30    0      0   30    0.0   30.000   0.0   30  ...
# 2          3  885   30    0      0   30    0.0   30.000   0.0   30  ...
# 3          4  885   30    0      0   30    0.0   30.000   0.0   30  ...
# 4          5  885   30    0      0   30    0.0   30.000   0.0   30  ...
# ..       ...  ...  ...  ...    ...  ...    ...      ...   ...  ...  ...
# 432      433  930   30    0      0  930  340.2  895.812  70.2  140  ...
# 433      434  930   30    0      0  930  340.2  895.812  70.2  140  ...
# 434      435  930   30    0      0  930  340.2  895.812  70.2   60  ...
# 435      436  930   30    0      0  930  340.2  895.812  70.2   60  ...
# 436      437  930   30    0      0  930  340.2  895.812  70.2   60  ...
#
#          S    Ni    Cr    Cu    Mo  RedRatio     dA     dB     dC  Fatigue
# ...

# %%
del df['Sl. No.']
df
# Out:
#       NT  THT  THt  THQCr   CT     Ct       DT    Dt  QmT   TT  ...      S  \
# 0    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.022
# 1    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.017
# 2    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.015
# 3    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.024
# 4    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.022
# ..   ...  ...  ...    ...  ...    ...      ...   ...  ...  ...  ...    ...
# 432  930   30    0      0  930  340.2  895.812  70.2  140  160  ...  0.024
# 433  930   30    0      0  930  340.2  895.812  70.2  140  160  ...  0.015
# 434  930   30    0      0  930  340.2  895.812  70.2   60  200  ...  0.019
# 435  930   30    0      0  930  340.2  895.812  70.2   60  200  ...  0.024
# 436  930   30    0      0  930  340.2  895.812  70.2   60  200  ...  0.015
#
#        Ni    Cr    Cu    Mo  RedRatio     dA     dB     dC  Fatigue
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=437, step=1)

# %%
df['RedRatio']/100.0
# Out:
# 0       8.25
# 1       6.10
# 2      12.70
# 3      17.40
# 4       8.25
#        ...
# 432     2.40
# 433     5.30
# 434     6.90
# 435     2.40
# 436     5.30
# Name: RedRatio, Length: 437, dtype: float64

# %%
df['RedRatio']>500
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 432    False
# 433     True
# 434     True
# 435    False
# 436     True
# Name: RedRatio, Length: 437, dtype: bool

# %%
df[ df['RedRatio'] == 500 ]
# Out:
#       NT  THT  THt  THQCr  CT   Ct    DT   Dt  QmT   TT  ...      S    Ni  \
# 141  870  855   30      8  30  0.0  30.0  0.0   30  550  ...  0.011  0.12
# 148  870  855   30      8  30  0.0  30.0  0.0   30  550  ...  0.009  0.12
# 150  870  855   30      8  30  0.0  30.0  0.0   30  550  ...  0.013  0.11
# 155  870  855   30      8  30  0.0  30.0  0.0   30  600  ...  0.011  0.12
# 162  870  855   30      8  30  0.0  30.0  0.0   30  600  ...  0.009  0.12
# 164  870  855   30      8  30  0.0  30.0  0.0   30  600  ...  0.013  0.11
# 169  870  855   30      8  30  0.0  30.0  0.0   30  650  ...  0.011  0.12
# 176  870  855   30      8  30  0.0  30.0  0.0   30  650  ...  0.009  0.12
# 178  870  855   30      8  30  0.0  30.0  0.0   30  650  ...  0.013  0.11
# 180  870  855   30      8  30  0.0  30.0  0.0   30  550  ...  0.008  0.10
# 187  870  855   30      8  30  0.0  30.0  0.0   30  550  ...  0.017  0.12
# 189  870  855   30      8  30  0.0  30.0  0.0   30  550  ...  0.017  0.13
# ...

# %%
df['Fatigue'].describe()
# Out:
# count     437.000000
# mean      552.903890
# std       186.630528
# min       225.000000
# 25%       448.000000
# 50%       505.000000
# 75%       578.000000
# max      1190.000000
# Name: Fatigue, dtype: float64

# %%
df.describe()
# Out:
#                NT         THT         THt       THQCr          CT          Ct  \
# count  437.000000  437.000000  437.000000  437.000000  437.000000  437.000000
# mean   872.299771  737.643021   25.949657   10.654462  128.855835   40.502059
# std     26.212073  280.036541   10.263824    7.841437  281.743539  126.924697
# min    825.000000   30.000000    0.000000    0.000000   30.000000    0.000000
# 25%    865.000000  845.000000   30.000000    8.000000   30.000000    0.000000
# 50%    870.000000  845.000000   30.000000    8.000000   30.000000    0.000000
# 75%    870.000000  855.000000   30.000000    8.000000   30.000000    0.000000
# max    930.000000  865.000000   30.000000   24.000000  930.000000  540.000000
#
#                DT          Dt         QmT          TT  ...           S  \
# count  437.000000  437.000000  437.000000  437.000000  ...  437.000000
# mean   123.699844    4.843936   35.491991  536.842105  ...    0.014611
# ...

# %%
df.isnull()
# Out:
#         NT    THT    THt  THQCr     CT     Ct     DT     Dt    QmT     TT  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 432  False  False  False  False  False  False  False  False  False  False
# 433  False  False  False  False  False  False  False  False  False  False
# 434  False  False  False  False  False  False  False  False  False  False
# 435  False  False  False  False  False  False  False  False  False  False
# 436  False  False  False  False  False  False  False  False  False  False
#
#      ...      S     Ni     Cr     Cu     Mo  RedRatio     dA     dB     dC  \
# ...

# %%
df.isnull().sum()
# Out:
# NT          0
# THT         0
# THt         0
# THQCr       0
# CT          0
# Ct          0
# DT          0
# Dt          0
# QmT         0
# TT          0
# Tt          0
# TCr         0
# C           0
# Si          0
# Mn          0
# P           0
# S           0
# Ni          0
# Cr          0
# Cu          0
# Mo          0
# RedRatio    0
# dA          0
# dB          0
# dC          0
# Fatigue     0
# dtype: int64

# %%
df.groupby('DT').Fatigue.mean()
# Out:
# DT
# 30.000      497.223650
# 850.000    1066.500000
# 881.807     979.333333
# 882.381     963.000000
# 895.517     978.444444
# 895.812     983.055556
# 903.333    1024.333333
# Name: Fatigue, dtype: float64

# %%
df.Fatigue.values
# Out:
# array([ 232,  235,  235,  241,  225,  245,  255,  245,  275,  239,  255,
#         397,  419,  401,  394,  426,  426,  454,  418,  416,  395,  433,
#         379,  382,  385,  365,  379,  377,  394,  425,  395,  393,  375,
#         389,  358,  344,  369,  325,  338,  362,  361,  385,  348,  368,
#         341,  365,  325,  513,  448,  465,  446,  437,  502,  465,  475,
#         504,  486,  452,  459,  415,  437,  415,  401,  463,  442,  438,
#         468,  452,  422,  413,  395,  398,  378,  372,  415,  396,  388,
#         415,  398,  382,  523,  534,  489,  500,  495,  522,  531,  533,
#         492,  505,  541,  468,  459,  444,  458,  445,  464,  466,  486,
#         461,  464,  475,  419,  418,  402,  398,  411,  428,  415,  425,
#         412,  410,  415,  582,  524,  583,  569,  536,  577,  565,  562,
#         522,  504,  516,  517,  511,  518,  524,  503,  483,  457,  482,
#         470,  459,  490,  485,  483,  587,  571,  578,  526,  535,  572,
# ...

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as mplot

# %%
y = df['Fatigue']
x1 = df['CT']
x2 = df['dA']

# %%
mplot.ylabel('Fatigue Strength',fontsize=10)
mplot.xlabel('Area Proportion of Inclusions Deformed by Plastic Work',fontsize=10)
mplot.plot(x2,y)

# %%
mplot.scatter(x2,y)

# %%
mplot.hist(df['Fatigue'],bins=15)
# Out:
# (array([ 11.,   6.,  61.,  88., 119.,  75.,  11.,   7.,   6.,   6.,  11.,
#           8.,  14.,  11.,   3.]),
#  array([ 225.        ,  289.33333333,  353.66666667,  418.        ,
#          482.33333333,  546.66666667,  611.        ,  675.33333333,
#          739.66666667,  804.        ,  868.33333333,  932.66666667,
#          997.        , 1061.33333333, 1125.66666667, 1190.        ]),
#  <BarContainer object of 15 artists>)

# %%
import seaborn as sns

# %%
sns.histplot(df['dA'])
# Out:
# <Axes: xlabel='dA', ylabel='Count'>

# %%
df.dA
# Out:
# 0      0.070
# 1      0.110
# 2      0.070
# 3      0.060
# 4      0.040
#        ...
# 432    0.050
# 433    0.017
# 434    0.080
# 435    0.050
# 436    0.017
# Name: dA, Length: 437, dtype: float64

# %%
df['dA']
# Out:
# 0      0.070
# 1      0.110
# 2      0.070
# 3      0.060
# 4      0.040
#        ...
# 432    0.050
# 433    0.017
# 434    0.080
# 435    0.050
# 436    0.017
# Name: dA, Length: 437, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

features = df.columns

# Plotting histograms for all feature columns
plt.figure(figsize=(10, 25))
for i, column in enumerate(features):
    ax = plt.subplot(len(features) // 4 + 1, 4, i + 1)
    sns.histplot(data=df, x=column, kde=True)

plt.tight_layout()
plt.show()

# %%
# Calculate the correlation matrix
corr = df.corr()

# Draw the heatmap of correlation matrix
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corr, annot=True, ax=ax, cmap='coolwarm', fmt=".1f", 
            linewidths=.5, cbar_kws={"shrink": .5})
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.yticks(rotation=0, fontsize=14)
plt.title('Correlation Matrix', fontsize=16)
plt.show()

# %% [markdown]
# ### t-SNE (Distributed Stochastic Neighbor Embedding)
#
# -Distributed stochastic neighbor embedding (t-SNE) is a statistical method for visualizing high-dimensional data by giving each datapoint a location in a two or three-dimensional map. (Read more here: https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding)
#
# -Transforming the 25-dimensional feature space onto 2-dimension reveals that samples are in clusters, with a cluster of high fatigue strength separating far from all other clusters. Our job is basically find the set of experimental conditions that corresponds to that cluster.
#
# -Also, within each cluster, data points also form strings, which means that these experiments are often done in series with slight modification on conditions, leading to the closeness in the high dimensional space.

# %%
from sklearn.manifold import TSNE

# Separating features and labels
X = df.drop('Fatigue', axis=1)
y = df['Fatigue']

# Performing t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=40)
X_tsne = tsne.fit_transform(X)

# Creating a scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y)
plt.title('t-SNE visualization of Fatigue')
plt.xlabel('t-SNE feature 1')
plt.ylabel('t-SNE feature 2')
plt.legend(title='Fatigue')
plt.show()

# %%
df
# Out:
#       NT  THT  THt  THQCr   CT     Ct       DT    Dt  QmT   TT  ...      S  \
# 0    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.022
# 1    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.017
# 2    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.015
# 3    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.024
# 4    885   30    0      0   30    0.0   30.000   0.0   30   30  ...  0.022
# ..   ...  ...  ...    ...  ...    ...      ...   ...  ...  ...  ...    ...
# 432  930   30    0      0  930  340.2  895.812  70.2  140  160  ...  0.024
# 433  930   30    0      0  930  340.2  895.812  70.2  140  160  ...  0.015
# 434  930   30    0      0  930  340.2  895.812  70.2   60  200  ...  0.019
# 435  930   30    0      0  930  340.2  895.812  70.2   60  200  ...  0.024
# 436  930   30    0      0  930  340.2  895.812  70.2   60  200  ...  0.015
#
#        Ni    Cr    Cu    Mo  RedRatio     dA     dB     dC  Fatigue
# ...

# %% [markdown]
# # Train-Validation-Test Split

# %%
np.random.seed(2)

n = len(df)

n_val = int(0.2 * n)
n_test = int(0.2 * n)
n_train = n - (n_val + n_test)

idx = np.arange(n)
np.random.shuffle(idx)

df_shuffled = df.iloc[idx]

df_train = df_shuffled.iloc[:n_train].copy()
df_val = df_shuffled.iloc[n_train:n_train+n_val].copy()
df_test = df_shuffled.iloc[n_train+n_val:].copy()

# %%
y_train = df_train.Fatigue.values
y_val = df_val.Fatigue.values
y_test = df_test.Fatigue.values

del df_train['Fatigue']
del df_val['Fatigue']
del df_test['Fatigue']

# %% [markdown]
# # Determine Weights

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %% [markdown]
# # Select a first group of features

# %%
#base = ['NT'	,	'Ct',	'TT'	,'C',	'Si',	'Mn',	'P',	'Ni',	'Cr',	'Mo',	'RedRatio',	'dA']
base = ['NT',	'THT',	'THt'	,'THQCr',	'CT',	'Ct',	'DT',	'Dt',	'QmT',	'TT',	'Tt',	'TCr'	,'C',	'Si',	'Mn',	'P',	'S',	'Ni',	'Cr',	'Cu',	'Mo',	'RedRatio',	'dA',	'dB',	'dC']

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)

# %%
y_pred = w_0 + X_train.dot(w)

# %%
plt.figure(figsize=(6, 4))

sns.histplot(y_train, label='target', color='#220000', alpha=0.1, bins=40)
sns.histplot(y_pred, label='prediction', color='#0000aa', alpha=0.6, bins=40)

plt.legend()

plt.ylabel('Frequency')
plt.xlabel('Fatigue')
plt.title('Predictions vs actual distribution')

plt.show()

# %% [markdown]
# # Root Mean Squared Error

# %%
def rmse(y, y_pred):
    error = y_pred - y
    mse = (error ** 2).mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(3615.6031033833665)

# %% [markdown]
# # Meaning of Weights

# %%
feature_names = ['NT',	'THT',	'THt'	,'THQCr',	'CT',	'Ct',	'DT',	'Dt',	'QmT',	'TT',	'Tt',	'TCr'	,'C',	'Si',	'Mn',	'P',	'S',	'Ni',	'Cr',	'Cu',	'Mo',	'RedRatio',	'dA',	'dB',	'dC']


# Plot
plt.figure(figsize=(10, 6))
plt.bar(feature_names, w, color='b')
plt.axhline(0, color='black', linewidth=1, linestyle='dashed')
plt.xlabel("Features")
plt.ylabel("Coefficient Value")
plt.title("Linear Regression Coefficients")
plt.xticks(rotation=45)
plt.show()

# %%
w
# Out:
# array([-2.74897000e+01,  1.16168417e+02, -9.43000750e+03,  2.47588385e+02,
#        -1.53474479e+02,  1.45625277e-01,  8.27811532e-01, -1.49701318e+00,
#        -3.29739315e-01, -9.00540978e-01,  1.13705876e+03,  5.10075752e+03,
#         6.20086451e+02,  5.73975644e+01, -2.64003368e+01, -9.21386856e+02,
#         8.39567757e+02,  2.10700256e+01,  6.31144927e+01, -1.93772851e+02,
#         2.05250769e+02,  5.55546661e-03,  4.10382238e+02, -3.41991582e+02,
#         2.44374648e+02])

# %% [markdown]
# # Regularization

# %%
def train_linear_regression_reg(X, y, r=0.0):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    reg = r * np.eye(XTX.shape[0])
    XTX = XTX + reg

    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %%
#base = ['NT'	,	'Ct',	'TT'	,'C',	'Si',	'Mn',	'P',	'Ni',	'Cr',	'Mo',	'RedRatio',	'dA']
base = ['NT',	'THT',	'THt'	,'THQCr',	'CT',	'Ct',	'DT',	'Dt',	'QmT',	'TT',	'Tt',	'TCr'	,'C',	'Si',	'Mn',	'P',	'S',	'Ni',	'Cr',	'Cu',	'Mo',	'RedRatio',	'dA',	'dB',	'dC']
X_train = prepare_X(df_train)

for r in [0, 0.001, 0.01, 0.1, 1, 10]:
    w_0, w = train_linear_regression_reg(X_train, y_train, r=r)
    print('%5s, %.2f, %.2f, %.2f' % (r, w_0, w[1], w[2]))
# Out:
#     0, 22902.90, 116.17, -9430.01
# 0.001, -91.55, 0.66, -128.45
#  0.01, -38.71, 0.71, -53.97
#   0.1, 34.77, 0.34, 51.86
#     1, 23.42, -1.35, 44.44
#    10, 5.09, -1.80, 21.19

# %%
for r in [0, 0.000001, 0.0001, 0.001, 0.01, 0.1, 1, 5, 10]:
    w_0, w = train_linear_regression_reg(X_train, y_train, r=r)
    y_pred = w_0 + X_train.dot(w)
    print('%6s' %r, rmse(y_train, y_pred))
# Out:
#      0 3615.6031033833665
#  1e-06 30.445700229264165
# 0.0001 30.44589545545795
#  0.001 30.46033612535841
#   0.01 30.73082273937192
#    0.1 31.63112031568107
#      1 36.30653005324364
#      5 40.833563630847436
#     10 42.77138236990856

# %%
base = ['NT'	,	'Ct',	'TT'	,'C',	'Si',	'Mn',	'P',	'Ni',	'Cr',	'Mo',	'RedRatio',	'dA']

X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)
y_pred = w_0 + X_train.dot(w)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(72.01204999234731)

# %% [markdown]
# # Additional Features (functions of features)

# %%
base = ['NT'	,	'Ct',	'TT'	,'C',	'Si',	'Mn',	'P',	'Ni',	'Cr',	'Mo',	'RedRatio',	'dA']

# %%
def prepare_X_math(df):
    df_num = df[base]
    df_num['colnew']=df_num['P']*df_num['dA']
    df_num = df_num.fillna(0)
    df_num.head()
    X = df_num.values
    return X

# %%
X_train = prepare_X_math(df_train)
w_0, w = train_linear_regression(X_train, y_train)
# Out:
# C:\Users\ayber\AppData\Local\Temp\ipykernel_39896\310114977.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num['colnew']=df_num['P']*df_num['dA']

# %%
y_pred2 = w_0 + X_train.dot(w)
rmse(y_train, y_pred2)
# Out:
# np.float64(72.00410737525432)

# %%
plt.figure(figsize=(6, 4))

sns.histplot(y_train, label='target', color='#220000', alpha=0.6, bins=40)
sns.histplot(y_pred, label='prediction', color='#0000aa', alpha=0.8, bins=40)
sns.histplot(y_pred2, label='additional features', color='#000a0a', alpha=0.8, bins=40)

plt.legend()

plt.ylabel('Frequency')
plt.xlabel('csMPa')
plt.title('Predictions vs actual distribution')

plt.show()

# %% [markdown]
# # LASSO

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

base = ['NT',	'THT',	'THt'	,'THQCr',	'CT',	'Ct',	'DT',	'Dt',	'QmT',	'TT',	'Tt',	'TCr'	,'C',	'Si',	'Mn',	'P',	'S',	'Ni',	'Cr',	'Cu',	'Mo',	'RedRatio',	'dA',	'dB',	'dC']
X_train = prepare_X(df_train)


lasso_regressor.fit(X_train,y_train)
print(lasso_regressor.best_params_)
print(np.sqrt(-1.0*lasso_regressor.best_score_))
# Out:
# c:\Users\ayber\OneDrive\Masaüstü\ML\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.000e+05, tolerance: 6.736e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ayber\OneDrive\Masaüstü\ML\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.043e+05, tolerance: 7.179e+02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
prediction_lasso=lasso_regressor.predict(X_train)

# %%
plt.figure(figsize=(6, 4))

sns.histplot(prediction_lasso, label='lasso', color='#00aa00', alpha=0.2, bins=40)
sns.histplot(y_train, label='target', color='#220000', alpha=0.8, bins=40)
sns.histplot(y_pred, label='pred', color='#0000aa', alpha=0.6, bins=40)


plt.legend()

plt.ylabel('Frequency')
plt.xlabel('Fatigue')
plt.title('Predictions vs actual distribution')

plt.show()

# %%
print(lasso_regressor.best_estimator_.coef_)
# Out:
# [ 1.48860015e+00 -3.09201290e-01 -3.77076689e+00 -2.84496033e+00
#   4.93251762e-01  1.34480655e-01  6.96858160e-02 -1.15923953e+00
#  -3.02973711e-01 -9.03093793e-01  2.53015579e+00  3.85571118e+01
#   6.44934046e+02  6.23548789e+01 -3.26385390e+01 -9.23447160e+02
#   6.91358606e+02  1.13816435e+01  6.41519332e+01 -1.80836192e+02
#   2.35523073e+02  5.95940825e-03  3.99723641e+02 -1.82482196e+02
#   1.76989871e+02]

# %%
w_0, w = train_linear_regression(X_train, y_train)
print(w)
# Out:
# [-2.74897000e+01  1.16168417e+02 -9.43000750e+03  2.47588385e+02
#  -1.53474479e+02  1.45625277e-01  8.27811532e-01 -1.49701318e+00
#  -3.29739315e-01 -9.00540978e-01  1.13705876e+03  5.10075752e+03
#   6.20086451e+02  5.73975644e+01 -2.64003368e+01 -9.21386856e+02
#   8.39567757e+02  2.10700256e+01  6.31144927e+01 -1.93772851e+02
#   2.05250769e+02  5.55546661e-03  4.10382238e+02 -3.41991582e+02
#   2.44374648e+02]
