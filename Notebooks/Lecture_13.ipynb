# %%
import requests
import json

base_url = 'http://nomad-lab.eu/prod/v1/api/v1'

response = requests.post(
    f'{base_url}/entries/query',
    json={
  "owner": "visible",
  "query": {
    "results.properties.available_properties:all": [
      "electronic.band_structure_electronic.band_gap"
    ],
    "results.material.elements:all": [
      "Ni",
      "Cu"
    ]
  }
})
response_json = response.json()
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "owner": "visible",
#   "query": {
#     "and": [
#       {
#         "name": "results.properties.available_properties",
#         "value": {
#           "all": [
#             "electronic.band_structure_electronic.band_gap"
#           ]
#         }
#       },
#       {
#         "name": "results.material.elements",
#         "value": {
#           "all": [
#             "Ni",
#             "Cu"
#           ]
#         }
#       }
#     ]
#   },
#   "pagination": {
#     "page_size": 10,
#     "order_by": "entry_id",
#     "order": "asc",
#     "total": 822,
#     "next_page_after_value": "-ldqK9wLvTx97YriYbnSMFd7DtCf"
#   },
#   "data": [
#     {
#       "upload_id": "GaUS1MToTwaP60R_e-vIDQ",
#       "references": [
#         "http://aflowlib.org",
#         "http://www.sciencedirect.com/science/article/pii/S0927025614003322",
#         "http://www.sciencedirect.com/science/article/pii/S0927025612000687"
#       ],
#       "origin": "AFLOW",
#       "quantities": [
#         "",
#         ".metadata",
#         ".results",
#         ".run",
#         ".workflow",
#         "metadata",
#         "metadata.calc_hash",
#         "metadata.calc_id",
#         "metadata.coauthors",
#         "metadata.datasets",
#         "metadata.domain",
#         "metadata.embargo_length",
#         "metadata.entry_coauthors",
#         "metadata.entry_create_time",
#         "metadata.external_db",
#         "metadata.files",
#         "metadata.last_processing_time",
#         "metadata.license",
#         "metadata.main_author",
#         "metadata.mainfile",
#         "metadata.nomad_commit",
#         "metadata.nomad_version",
#         "metadata.optimade",
#         "metadata.optimade.cartesian_site_positions",
#         "metadata.optimade.chemical_formula_anonymous",
#         "metadata.optimade.chemical_formula_descriptive",
#         "metadata.optimade.chemical_formula_hill",
#         "metadata.optimade.chemical_formula_reduced",
#         "metadata.optimade.dimension_types",
#         "metadata.optimade.elements",
#         "metadata.optimade.elements_ratios",
#         "metadata.optimade.lattice_vectors",
#         "metadata.optimade.nelements",
#         "metadata.optimade.nsites",
#         "metadata.optimade.species",
#         "metadata.optimade.species.chemical_symbols",
#         "metadata.optimade.species.concentration",
#         "metadata.optimade.species.name",
#         "metadata.optimade.species_at_sites",
#         "metadata.optimade.structure_features",
#         "metadata.parser_name",
#         "metadata.pid",
#         "metadata.processed",
#         "metadata.processing_errors",
#         "metadata.publish_time",
#         "metadata.published",
#         "metadata.references",
#         "metadata.reviewers",
#         "metadata.upload_create_time",
#         "metadata.upload_id",
#         "metadata.upload_name",
#         "metadata.with_embargo",
#         "results",
#         "results.material",
#         "results.material.chemical_formula_anonymous",
#         "results.material.chemical_formula_descriptive",
#         "results.material.chemical_formula_hill",
#         "results.material.chemical_formula_reduced",
#         "results.material.chemical_formula_reduced_fragments",
#         "results.material.elements",
#         "results.material.material_id",
#         "results.material.structural_type",
#         "results.material.symmetry",
#         "results.material.symmetry.bravais_lattice",
#         "results.material.symmetry.crystal_system",
#         "results.material.symmetry.hall_number",
#         "results.material.symmetry.hall_symbol",
#         "results.material.symmetry.point_group",
#         "results.material.symmetry.space_group_number",
#         "results.material.symmetry.space_group_symbol",
#         "results.method",
#         "results.method.method_name",
#         "results.method.parameter_variation_id",
#         "results.method.simulation",
#         "results.method.simulation.dft",
#         "results.method.simulation.dft.basis_set_type",
#         "results.method.simulation.dft.core_electron_treatment",
#         "results.method.simulation.dft.scf_threshold_energy_change",
#         "results.method.simulation.dft.xc_functional_names",
#         "results.method.simulation.dft.xc_functional_type",
#         "results.method.simulation.program_name",
#         "results.method.simulation.program_version",
#         "results.properties",
#         "results.properties.available_properties",
#         "results.properties.electronic",
#         "results.properties.electronic.band_structure_electronic",
#         "results.properties.electronic.band_structure_electronic.band_gap",
#         "results.properties.electronic.band_structure_electronic.band_gap.energy_highest_occupied",
#         "results.properties.electronic.band_structure_electronic.band_gap.energy_lowest_unoccupied",
#         "results.properties.electronic.band_structure_electronic.band_gap.index",
#         "results.properties.electronic.band_structure_electronic.band_gap.value",
#         "results.properties.electronic.band_structure_electronic.reciprocal_cell",
#         "results.properties.electronic.band_structure_electronic.segment",
#         "results.properties.electronic.band_structure_electronic.spin_polarized",
#         "results.properties.n_calculations",
#         "results.properties.structures",
#         "results.properties.structures.structure_conventional",
#         "results.properties.structures.structure_conventional.atomic_density",
#         "results.properties.structures.structure_conventional.cartesian_site_positions",
#         "results.properties.structures.structure_conventional.cell_volume",
#         "results.properties.structures.structure_conventional.dimension_types",
#         "results.properties.structures.structure_conventional.lattice_parameters",
#         "results.properties.structures.structure_conventional.lattice_parameters.a",
#         "results.properties.structures.structure_conventional.lattice_parameters.alpha",
#         "results.properties.structures.structure_conventional.lattice_parameters.b",
#         "results.properties.structures.structure_conventional.lattice_parameters.beta",
#         "results.properties.structures.structure_conventional.lattice_parameters.c",
#         "results.properties.structures.structure_conventional.lattice_parameters.gamma",
#         "results.properties.structures.structure_conventional.lattice_vectors",
#         "results.properties.structures.structure_conventional.mass_density",
#         "results.properties.structures.structure_conventional.species",
#         "results.properties.structures.structure_conventional.species.chemical_symbols",
#         "results.properties.structures.structure_conventional.species.concentration",
#         "results.properties.structures.structure_conventional.species.name",
#         "results.properties.structures.structure_conventional.species_at_sites",
#         "results.properties.structures.structure_conventional.wyckoff_sets",
#         "results.properties.structures.structure_conventional.wyckoff_sets.element",
#         "results.properties.structures.structure_conventional.wyckoff_sets.indices",
#         "results.properties.structures.structure_conventional.wyckoff_sets.wyckoff_letter",
#         "results.properties.structures.structure_conventional.wyckoff_sets.x",
#         "results.properties.structures.structure_conventional.wyckoff_sets.y",
#         "results.properties.structures.structure_conventional.wyckoff_sets.z",
#         "results.properties.structures.structure_original",
#         "results.properties.structures.structure_original.atomic_density",
#         "results.properties.structures.structure_original.cartesian_site_positions",
#         "results.properties.structures.structure_original.cell_volume",
#         "results.properties.structures.structure_original.dimension_types",
#         "results.properties.structures.structure_original.lattice_parameters",
#         "results.properties.structures.structure_original.lattice_parameters.a",
#         "results.properties.structures.structure_original.lattice_parameters.alpha",
#         "results.properties.structures.structure_original.lattice_parameters.b",
#         "results.properties.structures.structure_original.lattice_parameters.beta",
#         "results.properties.structures.structure_original.lattice_parameters.c",
#         "results.properties.structures.structure_original.lattice_parameters.gamma",
#         "results.properties.structures.structure_original.lattice_vectors",
#         "results.properties.structures.structure_original.mass_density",
#         "results.properties.structures.structure_original.species",
#         "results.properties.structures.structure_original.species.chemical_symbols",
#         "results.properties.structures.structure_original.species.concentration",
#         "results.properties.structures.structure_original.species.name",
#         "results.properties.structures.structure_original.species_at_sites",
#         "results.properties.structures.structure_primitive",
#         "results.properties.structures.structure_primitive.atomic_density",
#         "results.properties.structures.structure_primitive.cartesian_site_positions",
#         "results.properties.structures.structure_primitive.cell_volume",
#         "results.properties.structures.structure_primitive.dimension_types",
#         "results.properties.structures.structure_primitive.lattice_parameters",
#         "results.properties.structures.structure_primitive.lattice_parameters.a",
#         "results.properties.structures.structure_primitive.lattice_parameters.alpha",
#         "results.properties.structures.structure_primitive.lattice_parameters.b",
#         "results.properties.structures.structure_primitive.lattice_parameters.beta",
#         "results.properties.structures.structure_primitive.lattice_parameters.c",
#         "results.properties.structures.structure_primitive.lattice_parameters.gamma",
#         "results.properties.structures.structure_primitive.lattice_vectors",
#         "results.properties.structures.structure_primitive.mass_density",
#         "results.properties.structures.structure_primitive.species",
#         "results.properties.structures.structure_primitive.species.chemical_symbols",
#         "results.properties.structures.structure_primitive.species.concentration",
#         "results.properties.structures.structure_primitive.species.name",
#         "results.properties.structures.structure_primitive.species_at_sites",
#         "run",
#         "run.calculation",
#         "run.calculation.band_structure_electronic",
#         "run.calculation.band_structure_electronic.band_gap",
#         "run.calculation.band_structure_electronic.band_gap.energy_highest_occupied",
#         "run.calculation.band_structure_electronic.band_gap.energy_lowest_unoccupied",
#         "run.calculation.band_structure_electronic.band_gap.index",
#         "run.calculation.band_structure_electronic.band_gap.value",
#         "run.calculation.band_structure_electronic.reciprocal_cell",
#         "run.calculation.band_structure_electronic.segment",
#         "run.calculation.band_structure_electronic.segment.energies",
#         "run.calculation.band_structure_electronic.segment.kpoints",
#         "run.calculation.band_structure_electronic.segment.occupations",
#         "run.calculation.energy",
#         "run.calculation.energy.free",
#         "run.calculation.energy.free.value",
#         "run.calculation.energy.highest_occupied",
#         "run.calculation.energy.lowest_unoccupied",
#         "run.calculation.energy.total",
#         "run.calculation.energy.total.value",
#         "run.calculation.energy.total_t0",
#         "run.calculation.energy.total_t0.value",
#         "run.calculation.forces",
#         "run.calculation.forces.total",
#         "run.calculation.forces.total.value",
#         "run.calculation.method_ref",
#         "run.calculation.scf_iteration",
#         "run.calculation.scf_iteration.energy",
#         "run.calculation.scf_iteration.energy.correction_hartree",
#         "run.calculation.scf_iteration.energy.correction_hartree.value",
#         "run.calculation.scf_iteration.energy.free",
#         "run.calculation.scf_iteration.energy.free.value",
#         "run.calculation.scf_iteration.energy.total",
#         "run.calculation.scf_iteration.energy.total.value",
#         "run.calculation.scf_iteration.energy.total_t0",
#         "run.calculation.scf_iteration.energy.total_t0.value",
#         "run.calculation.scf_iteration.energy.xc",
#         "run.calculation.scf_iteration.energy.xc.value",
#         "run.calculation.stress",
#         "run.calculation.stress.total",
#         "run.calculation.stress.total.value",
#         "run.calculation.system_ref",
#         "run.method",
#         "run.method.atom_parameters",
#         "run.method.atom_parameters.atom_number",
#         "run.method.atom_parameters.label",
#         "run.method.atom_parameters.mass",
#         "run.method.atom_parameters.n_valence_electrons",
#         "run.method.atom_parameters.pseudopotential_name",
#         "run.method.basis_set",
#         "run.method.basis_set.cell_dependent",
#         "run.method.basis_set.cell_dependent.kind",
#         "run.method.basis_set.cell_dependent.planewave_cutoff",
#         "run.method.basis_set.type",
#         "run.method.dft",
#         "run.method.dft.xc_functional",
#         "run.method.dft.xc_functional.correlation",
#         "run.method.dft.xc_functional.correlation.name",
#         "run.method.dft.xc_functional.exchange",
#         "run.method.dft.xc_functional.exchange.name",
#         "run.method.dft.xc_functional.name",
#         "run.method.electronic",
#         "run.method.electronic.method",
#         "run.method.scf",
#         "run.method.scf.threshold_energy_change",
#         "run.program",
#         "run.program.compilation_datetime",
#         "run.program.name",
#         "run.program.version",
#         "run.system",
#         "run.system.atoms",
#         "run.system.atoms.labels",
#         "run.system.atoms.lattice_vectors",
#         "run.system.atoms.periodic",
#         "run.system.atoms.positions",
#         "run.system.atoms.species",
#         "run.system.chemical_composition",
#         "run.system.chemical_composition_hill",
#         "run.system.chemical_composition_reduced",
#         "run.system.configuration_raw_gid",
#         "run.system.is_representative",
#         "run.system.symmetry",
#         "run.system.symmetry.bravais_lattice",
#         "run.system.symmetry.crystal_system",
#         "run.system.symmetry.hall_number",
#         "run.system.symmetry.hall_symbol",
#         "run.system.symmetry.international_short_symbol",
#         "run.system.symmetry.origin_shift",
#         "run.system.symmetry.point_group",
#         "run.system.symmetry.space_group_number",
#         "run.system.symmetry.symmetry_method",
#         "run.system.symmetry.system_original",
#         "run.system.symmetry.system_original.equivalent_atoms",
#         "run.system.symmetry.system_original.wyckoff_letters",
#         "run.system.symmetry.system_primitive",
#         "run.system.symmetry.system_primitive.atomic_numbers",
#         "run.system.symmetry.system_primitive.equivalent_atoms",
#         "run.system.symmetry.system_primitive.lattice_vectors",
#         "run.system.symmetry.system_primitive.positions",
#         "run.system.symmetry.system_primitive.wyckoff_letters",
#         "run.system.symmetry.system_std",
#         "run.system.symmetry.system_std.atomic_numbers",
#         "run.system.symmetry.system_std.equivalent_atoms",
#         "run.system.symmetry.system_std.lattice_vectors",
#         "run.system.symmetry.system_std.positions",
#         "run.system.symmetry.system_std.wyckoff_letters",
#         "run.system.symmetry.transformation_matrix",
#         "run.system.type",
#         "workflow",
#         "workflow.calculation_result_ref",
#         "workflow.calculations_ref",
#         "workflow.single_point",
#         "workflow.single_point.final_scf_energy_difference",
#         "workflow.single_point.is_converged",
#         "workflow.single_point.method",
#         "workflow.single_point.n_scf_steps",
#         "workflow.single_point.with_bandstructure",
#         "workflow.single_point.with_density_of_states",
#         "workflow.single_point.with_eigenvalues",
#         "workflow.single_point.with_excited_states",
#         "workflow.single_point.with_volumetric_data",
#         "workflow.type"
#       ],
#       "pid": "4203205",
#       "datasets": [],
#       "n_quantities": 488,
#       "nomad_version": "1.0.0",
#       "upload_create_time": "2015-10-03T15:06:11.967000",
#       "nomad_commit": "37587aa6",
#       "publish_time": "2015-10-03T15:06:11.967000",
#       "processing_errors": [],
#       "results": {
#         "material": {
#           "symmetry": {
#             "bravais_lattice": "oS",
#             "space_group_symbol": "Cmmm",
#             "space_group_number": 65,
#             "point_group": "mmm",
#             "crystal_system": "orthorhombic",
#             "hall_number": 310,
#             "hall_symbol": "-C 2 2"
#           },
#           "elements": [
#             "Cu",
#             "Ni",
#             "Os"
#           ],
#           "elements_exclusive": "Cu Ni Os",
#           "chemical_formula_anonymous": "A24B4C4",
#           "material_id": "x2LOP0vVawDa0wSwoxh6Yi8yoOqw",
#           "structural_type": "bulk",
#           "chemical_formula_reduced": "Cu4Ni24Os4",
#           "n_elements": 3,
#           "chemical_formula_descriptive": "Cu4Ni24Os4",
#           "chemical_formula_reduced_fragments": [
#             "Cu",
#             "Ni6",
#             "Os"
#           ],
#           "chemical_formula_hill": "Cu4Ni24Os4"
#         },
#         "method": {
#           "method_name": "DFT",
#           "simulation": {
#             "program_version": "4.6.35 3Apr08 complex parallel LinuxIFC",
#             "dft": {
#               "basis_set_type": "plane waves",
#               "core_electron_treatment": "pseudopotential",
#               "xc_functional_type": "GGA",
#               "xc_functional_names": [
#                 "GGA_C_PBE",
#                 "GGA_X_PBE"
#               ],
#               "scf_threshold_energy_change": 1.602176634e-23
#             },
#             "program_name": "VASP"
#           }
#         },
#         "properties": {
#           "available_properties": [
#             "band_structure_electronic",
#             "electronic.band_structure_electronic.band_gap"
#           ],
#           "n_calculations": 1,
#           "structures": {
#             "structure_primitive": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 32,
#               "cell_volume": 3.638638917773514e-28,
#               "lattice_parameters": {
#                 "a": 6.180555079290332e-10,
#                 "b": 6.180555079290332e-10,
#                 "c": 1.0095124780000002e-09,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.9083548653349007
#               }
#             },
#             "structure_conventional": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 64,
#               "cell_volume": 7.277277835547042e-28,
#               "lattice_parameters": {
#                 "a": 7.148183220000001e-10,
#                 "b": 1.008466762e-09,
#                 "c": 1.0095124780000002e-09,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.5707963267948966
#               }
#             },
#             "structure_original": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 32,
#               "cell_volume": 3.638638917773514e-28,
#               "lattice_parameters": {
#                 "a": 6.180555079290332e-10,
#                 "b": 6.180555079290332e-10,
#                 "c": 1.0095124780000002e-09,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.9083548653349007
#               }
#             }
#           },
#           "electronic": {
#             "band_structure_electronic": {
#               "spin_polarized": true,
#               "band_gap": [
#                 {
#                   "index": 0,
#                   "value": 0.0
#                 },
#                 {
#                   "index": 1,
#                   "value": 0.0
#                 }
#               ]
#             }
#           }
#         }
#       },
#       "last_processing_time": "2021-12-26T14:01:14.068000",
#       "optimade": {
#         "nperiodic_dimensions": 3,
#         "species_at_sites": [
#           "Cu",
#           "Cu",
#           "Cu",
#           "Cu",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Os",
#           "Os",
#           "Os",
#           "Os"
#         ],
#         "nsites": 32,
#         "elements": [
#           "Cu",
#           "Ni",
#           "Os"
#         ],
#         "chemical_formula_anonymous": "A24B4C4",
#         "chemical_formula_reduced": "Cu4Ni24Os4",
#         "structure_features": [],
#         "nelements": 3,
#         "chemical_formula_descriptive": "Cu4Ni24Os4",
#         "chemical_formula_hill": "Cu4Ni24Os4",
#         "elements_ratios": [
#           [
#             {
#               "elements": "Cu",
#               "elements_ratios": 0.125
#             },
#             {
#               "elements": "Ni",
#               "elements_ratios": 0.75
#             },
#             {
#               "elements": "Os",
#               "elements_ratios": 0.125
#             }
#           ],
#           [
#             {
#               "elements": "Cu",
#               "elements_ratios": 0.125
#             },
#             {
#               "elements": "Ni",
#               "elements_ratios": 0.75
#             },
#             {
#               "elements": "Os",
#               "elements_ratios": 0.125
#             }
#           ],
#           [
#             {
#               "elements": "Cu",
#               "elements_ratios": 0.125
#             },
#             {
#               "elements": "Ni",
#               "elements_ratios": 0.75
#             },
#             {
#               "elements": "Os",
#               "elements_ratios": 0.125
#             }
#           ]
#         ]
#       },
#       "parser_name": "parsers/vasp",
#       "calc_id": "--68O6KEt0GF5R9scUaiEpcvbXiG",
#       "published": true,
#       "writers": [
#         {
#           "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#           "name": "Stefano Curtarolo"
#         },
#         {
#           "user_id": "d2621bc7-c45a-4d35-9dc1-5c05fa8326cb",
#           "name": "Frisco Rose"
#         },
#         {
#           "user_id": "9c308f66-eed1-4996-b33e-af78fb4944c7",
#           "name": "Richard Taylor"
#         },
#         {
#           "user_id": "d63d07e6-ccc8-4eac-82af-d841627b6c53",
#           "name": "Ohad Levy"
#         },
#         {
#           "user_id": "48e7a028-1a41-440d-9986-38540f5079c9",
#           "name": "Cormac Toher"
#         },
#         {
#           "user_id": "7b3fe468-0011-4ba8-bd53-1ee65acda114",
#           "name": "Marco Buongiorno Nardelli"
#         },
#         {
#           "user_id": "f7b540eb-a266-4379-9611-911ed8e3630e",
#           "name": "Wahyu Setyawan"
#         },
#         {
#           "user_id": "3df68fed-6ca0-4bf9-b2b1-d6be71e18f72",
#           "name": "Shidong Wang"
#         },
#         {
#           "user_id": "ecba0e68-65ee-4b40-8fbf-a42714b1072b",
#           "name": "Junkai Xue"
#         },
#         {
#           "user_id": "f409d859-2639-4f82-b198-85e1c7c62f8b",
#           "name": "Kesong Yang"
#         },
#         {
#           "user_id": "580f7036-97b8-42b1-a9e6-815058bcac72",
#           "name": "Lance Nelson"
#         },
#         {
#           "user_id": "4c8d767d-335f-4ccd-9459-d0152b2026bc",
#           "name": "Gus Hart"
#         },
#         {
#           "user_id": "7effd16a-a65c-4d95-b692-652488d94146",
#           "name": "Stefano Sanvito"
#         },
#         {
#           "user_id": "d59b3610-6335-4ad8-aca0-24a905de3a25",
#           "name": "Natalio Mingo"
#         }
#       ],
#       "processed": true,
#       "mainfile": "aflowlib_data/LIB3_LIB/Cu_pvNi_pvOs_pv/TS001.CAB/vasprun.xml.bands",
#       "main_author": {
#         "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#         "name": "Stefano Curtarolo"
#       },
#       "viewers": [
#         {
#           "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#           "name": "Stefano Curtarolo"
#         },
#         {
#           "user_id": "d2621bc7-c45a-4d35-9dc1-5c05fa8326cb",
#           "name": "Frisco Rose"
#         },
#         {
#           "user_id": "9c308f66-eed1-4996-b33e-af78fb4944c7",
#           "name": "Richard Taylor"
#         },
#         {
#           "user_id": "d63d07e6-ccc8-4eac-82af-d841627b6c53",
#           "name": "Ohad Levy"
#         },
#         {
#           "user_id": "48e7a028-1a41-440d-9986-38540f5079c9",
#           "name": "Cormac Toher"
#         },
#         {
#           "user_id": "7b3fe468-0011-4ba8-bd53-1ee65acda114",
#           "name": "Marco Buongiorno Nardelli"
#         },
#         {
#           "user_id": "f7b540eb-a266-4379-9611-911ed8e3630e",
#           "name": "Wahyu Setyawan"
#         },
#         {
#           "user_id": "3df68fed-6ca0-4bf9-b2b1-d6be71e18f72",
#           "name": "Shidong Wang"
#         },
#         {
#           "user_id": "ecba0e68-65ee-4b40-8fbf-a42714b1072b",
#           "name": "Junkai Xue"
#         },
#         {
#           "user_id": "f409d859-2639-4f82-b198-85e1c7c62f8b",
#           "name": "Kesong Yang"
#         },
#         {
#           "user_id": "580f7036-97b8-42b1-a9e6-815058bcac72",
#           "name": "Lance Nelson"
#         },
#         {
#           "user_id": "4c8d767d-335f-4ccd-9459-d0152b2026bc",
#           "name": "Gus Hart"
#         },
#         {
#           "user_id": "7effd16a-a65c-4d95-b692-652488d94146",
#           "name": "Stefano Sanvito"
#         },
#         {
#           "user_id": "d59b3610-6335-4ad8-aca0-24a905de3a25",
#           "name": "Natalio Mingo"
#         }
#       ],
#       "entry_create_time": "2019-07-20T16:31:45",
#       "with_embargo": false,
#       "external_db": "AFLOW",
#       "domain": "dft",
#       "files": [
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvOs_pv/TS001.CAB/vasprun.xml.bands",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvOs_pv/TS001.CAB/vasprun.xml.relax1",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvOs_pv/TS001.CAB/vasprun.xml.relax2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvOs_pv/TS001.CAB/vasprun.xml.static"
#       ],
#       "entry_id": "--68O6KEt0GF5R9scUaiEpcvbXiG",
#       "upload_name": "wsDcyo4OS4yqqcR1jypVAA",
#       "authors": [
#         {
#           "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#           "name": "Stefano Curtarolo"
#         },
#         {
#           "user_id": "d2621bc7-c45a-4d35-9dc1-5c05fa8326cb",
#           "name": "Frisco Rose"
#         },
#         {
#           "user_id": "9c308f66-eed1-4996-b33e-af78fb4944c7",
#           "name": "Richard Taylor"
#         },
#         {
#           "user_id": "d63d07e6-ccc8-4eac-82af-d841627b6c53",
#           "name": "Ohad Levy"
#         },
#         {
#           "user_id": "48e7a028-1a41-440d-9986-38540f5079c9",
#           "name": "Cormac Toher"
#         },
#         {
#           "user_id": "7b3fe468-0011-4ba8-bd53-1ee65acda114",
#           "name": "Marco Buongiorno Nardelli"
#         },
#         {
#           "user_id": "f7b540eb-a266-4379-9611-911ed8e3630e",
#           "name": "Wahyu Setyawan"
#         },
#         {
#           "user_id": "3df68fed-6ca0-4bf9-b2b1-d6be71e18f72",
#           "name": "Shidong Wang"
#         },
#         {
#           "user_id": "ecba0e68-65ee-4b40-8fbf-a42714b1072b",
#           "name": "Junkai Xue"
#         },
#         {
#           "user_id": "f409d859-2639-4f82-b198-85e1c7c62f8b",
#           "name": "Kesong Yang"
#         },
#         {
#           "user_id": "580f7036-97b8-42b1-a9e6-815058bcac72",
#           "name": "Lance Nelson"
#         },
#         {
#           "user_id": "4c8d767d-335f-4ccd-9459-d0152b2026bc",
#           "name": "Gus Hart"
#         },
#         {
#           "user_id": "7effd16a-a65c-4d95-b692-652488d94146",
#           "name": "Stefano Sanvito"
#         },
#         {
#           "user_id": "d59b3610-6335-4ad8-aca0-24a905de3a25",
#           "name": "Natalio Mingo"
#         }
#       ],
#       "license": "CC BY 4.0"
#     },
#     {
#       "upload_id": "vCl6sMTYQ_eTH9Gui7YcoA",
#       "references": [
#         "http://www.sciencedirect.com/science/article/pii/S0927025612000687",
#         "http://aflowlib.org",
#         "http://www.sciencedirect.com/science/article/pii/S0927025614003322"
#       ],
#       "origin": "AFLOW",
#       "quantities": [
#         "",
#         ".metadata",
#         ".results",
#         ".run",
#         ".workflow",
#         "metadata",
#         "metadata.coauthors",
#         "metadata.datasets",
#         "metadata.domain",
#         "metadata.embargo_length",
#         "metadata.entry_coauthors",
#         "metadata.entry_create_time",
#         "metadata.entry_hash",
#         "metadata.entry_id",
#         "metadata.external_db",
#         "metadata.files",
#         "metadata.last_processing_time",
#         "metadata.license",
#         "metadata.main_author",
#         "metadata.mainfile",
#         "metadata.nomad_commit",
#         "metadata.nomad_version",
#         "metadata.optimade",
#         "metadata.optimade.cartesian_site_positions",
#         "metadata.optimade.chemical_formula_anonymous",
#         "metadata.optimade.chemical_formula_descriptive",
#         "metadata.optimade.chemical_formula_hill",
#         "metadata.optimade.chemical_formula_reduced",
#         "metadata.optimade.dimension_types",
#         "metadata.optimade.elements",
#         "metadata.optimade.elements_ratios",
#         "metadata.optimade.lattice_vectors",
#         "metadata.optimade.nelements",
#         "metadata.optimade.nsites",
#         "metadata.optimade.species",
#         "metadata.optimade.species.chemical_symbols",
#         "metadata.optimade.species.concentration",
#         "metadata.optimade.species.name",
#         "metadata.optimade.species_at_sites",
#         "metadata.optimade.structure_features",
#         "metadata.parser_name",
#         "metadata.pid",
#         "metadata.processed",
#         "metadata.processing_errors",
#         "metadata.publish_time",
#         "metadata.published",
#         "metadata.references",
#         "metadata.reviewers",
#         "metadata.upload_create_time",
#         "metadata.upload_id",
#         "metadata.upload_name",
#         "metadata.with_embargo",
#         "results",
#         "results.material",
#         "results.material.chemical_formula_anonymous",
#         "results.material.chemical_formula_descriptive",
#         "results.material.chemical_formula_hill",
#         "results.material.chemical_formula_reduced",
#         "results.material.chemical_formula_reduced_fragments",
#         "results.material.elements",
#         "results.material.material_id",
#         "results.material.structural_type",
#         "results.material.symmetry",
#         "results.material.symmetry.bravais_lattice",
#         "results.material.symmetry.crystal_system",
#         "results.material.symmetry.hall_number",
#         "results.material.symmetry.hall_symbol",
#         "results.material.symmetry.point_group",
#         "results.material.symmetry.prototype_aflow_id",
#         "results.material.symmetry.prototype_formula",
#         "results.material.symmetry.space_group_number",
#         "results.material.symmetry.space_group_symbol",
#         "results.material.symmetry.structure_name",
#         "results.material.symmetry.strukturbericht_designation",
#         "results.method",
#         "results.method.method_name",
#         "results.method.parameter_variation_id",
#         "results.method.simulation",
#         "results.method.simulation.dft",
#         "results.method.simulation.dft.basis_set_type",
#         "results.method.simulation.dft.core_electron_treatment",
#         "results.method.simulation.dft.scf_threshold_energy_change",
#         "results.method.simulation.dft.xc_functional_names",
#         "results.method.simulation.dft.xc_functional_type",
#         "results.method.simulation.program_name",
#         "results.method.simulation.program_version",
#         "results.properties",
#         "results.properties.available_properties",
#         "results.properties.electronic",
#         "results.properties.electronic.band_structure_electronic",
#         "results.properties.electronic.band_structure_electronic.band_gap",
#         "results.properties.electronic.band_structure_electronic.band_gap.energy_highest_occupied",
#         "results.properties.electronic.band_structure_electronic.band_gap.energy_lowest_unoccupied",
#         "results.properties.electronic.band_structure_electronic.band_gap.index",
#         "results.properties.electronic.band_structure_electronic.band_gap.value",
#         "results.properties.electronic.band_structure_electronic.reciprocal_cell",
#         "results.properties.electronic.band_structure_electronic.segment",
#         "results.properties.electronic.band_structure_electronic.spin_polarized",
#         "results.properties.n_calculations",
#         "results.properties.structures",
#         "results.properties.structures.structure_conventional",
#         "results.properties.structures.structure_conventional.atomic_density",
#         "results.properties.structures.structure_conventional.cartesian_site_positions",
#         "results.properties.structures.structure_conventional.cell_volume",
#         "results.properties.structures.structure_conventional.dimension_types",
#         "results.properties.structures.structure_conventional.lattice_parameters",
#         "results.properties.structures.structure_conventional.lattice_parameters.a",
#         "results.properties.structures.structure_conventional.lattice_parameters.alpha",
#         "results.properties.structures.structure_conventional.lattice_parameters.b",
#         "results.properties.structures.structure_conventional.lattice_parameters.beta",
#         "results.properties.structures.structure_conventional.lattice_parameters.c",
#         "results.properties.structures.structure_conventional.lattice_parameters.gamma",
#         "results.properties.structures.structure_conventional.lattice_vectors",
#         "results.properties.structures.structure_conventional.mass_density",
#         "results.properties.structures.structure_conventional.species",
#         "results.properties.structures.structure_conventional.species.chemical_symbols",
#         "results.properties.structures.structure_conventional.species.concentration",
#         "results.properties.structures.structure_conventional.species.name",
#         "results.properties.structures.structure_conventional.species_at_sites",
#         "results.properties.structures.structure_conventional.wyckoff_sets",
#         "results.properties.structures.structure_conventional.wyckoff_sets.element",
#         "results.properties.structures.structure_conventional.wyckoff_sets.indices",
#         "results.properties.structures.structure_conventional.wyckoff_sets.wyckoff_letter",
#         "results.properties.structures.structure_original",
#         "results.properties.structures.structure_original.atomic_density",
#         "results.properties.structures.structure_original.cartesian_site_positions",
#         "results.properties.structures.structure_original.cell_volume",
#         "results.properties.structures.structure_original.dimension_types",
#         "results.properties.structures.structure_original.lattice_parameters",
#         "results.properties.structures.structure_original.lattice_parameters.a",
#         "results.properties.structures.structure_original.lattice_parameters.alpha",
#         "results.properties.structures.structure_original.lattice_parameters.b",
#         "results.properties.structures.structure_original.lattice_parameters.beta",
#         "results.properties.structures.structure_original.lattice_parameters.c",
#         "results.properties.structures.structure_original.lattice_parameters.gamma",
#         "results.properties.structures.structure_original.lattice_vectors",
#         "results.properties.structures.structure_original.mass_density",
#         "results.properties.structures.structure_original.species",
#         "results.properties.structures.structure_original.species.chemical_symbols",
#         "results.properties.structures.structure_original.species.concentration",
#         "results.properties.structures.structure_original.species.name",
#         "results.properties.structures.structure_original.species_at_sites",
#         "results.properties.structures.structure_primitive",
#         "results.properties.structures.structure_primitive.atomic_density",
#         "results.properties.structures.structure_primitive.cartesian_site_positions",
#         "results.properties.structures.structure_primitive.cell_volume",
#         "results.properties.structures.structure_primitive.dimension_types",
#         "results.properties.structures.structure_primitive.lattice_parameters",
#         "results.properties.structures.structure_primitive.lattice_parameters.a",
#         "results.properties.structures.structure_primitive.lattice_parameters.alpha",
#         "results.properties.structures.structure_primitive.lattice_parameters.b",
#         "results.properties.structures.structure_primitive.lattice_parameters.beta",
#         "results.properties.structures.structure_primitive.lattice_parameters.c",
#         "results.properties.structures.structure_primitive.lattice_parameters.gamma",
#         "results.properties.structures.structure_primitive.lattice_vectors",
#         "results.properties.structures.structure_primitive.mass_density",
#         "results.properties.structures.structure_primitive.species",
#         "results.properties.structures.structure_primitive.species.chemical_symbols",
#         "results.properties.structures.structure_primitive.species.concentration",
#         "results.properties.structures.structure_primitive.species.name",
#         "results.properties.structures.structure_primitive.species_at_sites",
#         "run",
#         "run.calculation",
#         "run.calculation.band_structure_electronic",
#         "run.calculation.band_structure_electronic.band_gap",
#         "run.calculation.band_structure_electronic.band_gap.energy_highest_occupied",
#         "run.calculation.band_structure_electronic.band_gap.energy_lowest_unoccupied",
#         "run.calculation.band_structure_electronic.band_gap.index",
#         "run.calculation.band_structure_electronic.band_gap.value",
#         "run.calculation.band_structure_electronic.reciprocal_cell",
#         "run.calculation.band_structure_electronic.segment",
#         "run.calculation.band_structure_electronic.segment.endpoints_labels",
#         "run.calculation.band_structure_electronic.segment.energies",
#         "run.calculation.band_structure_electronic.segment.kpoints",
#         "run.calculation.band_structure_electronic.segment.occupations",
#         "run.calculation.energy",
#         "run.calculation.energy.free",
#         "run.calculation.energy.free.value",
#         "run.calculation.energy.highest_occupied",
#         "run.calculation.energy.lowest_unoccupied",
#         "run.calculation.energy.total",
#         "run.calculation.energy.total.value",
#         "run.calculation.energy.total_t0",
#         "run.calculation.energy.total_t0.value",
#         "run.calculation.forces",
#         "run.calculation.forces.total",
#         "run.calculation.forces.total.value",
#         "run.calculation.method_ref",
#         "run.calculation.scf_iteration",
#         "run.calculation.scf_iteration.energy",
#         "run.calculation.scf_iteration.energy.correction_hartree",
#         "run.calculation.scf_iteration.energy.correction_hartree.value",
#         "run.calculation.scf_iteration.energy.free",
#         "run.calculation.scf_iteration.energy.free.value",
#         "run.calculation.scf_iteration.energy.total",
#         "run.calculation.scf_iteration.energy.total.value",
#         "run.calculation.scf_iteration.energy.total_t0",
#         "run.calculation.scf_iteration.energy.total_t0.value",
#         "run.calculation.scf_iteration.energy.xc",
#         "run.calculation.scf_iteration.energy.xc.value",
#         "run.calculation.stress",
#         "run.calculation.stress.total",
#         "run.calculation.stress.total.value",
#         "run.calculation.system_ref",
#         "run.method",
#         "run.method.atom_parameters",
#         "run.method.atom_parameters.atom_number",
#         "run.method.atom_parameters.label",
#         "run.method.atom_parameters.mass",
#         "run.method.atom_parameters.n_valence_electrons",
#         "run.method.atom_parameters.pseudopotential_name",
#         "run.method.basis_set",
#         "run.method.basis_set.cell_dependent",
#         "run.method.basis_set.cell_dependent.kind",
#         "run.method.basis_set.cell_dependent.planewave_cutoff",
#         "run.method.basis_set.type",
#         "run.method.dft",
#         "run.method.dft.xc_functional",
#         "run.method.dft.xc_functional.correlation",
#         "run.method.dft.xc_functional.correlation.name",
#         "run.method.dft.xc_functional.exchange",
#         "run.method.dft.xc_functional.exchange.name",
#         "run.method.dft.xc_functional.name",
#         "run.method.electronic",
#         "run.method.electronic.method",
#         "run.method.scf",
#         "run.method.scf.threshold_energy_change",
#         "run.program",
#         "run.program.compilation_datetime",
#         "run.program.name",
#         "run.program.version",
#         "run.system",
#         "run.system.atoms",
#         "run.system.atoms.labels",
#         "run.system.atoms.lattice_vectors",
#         "run.system.atoms.periodic",
#         "run.system.atoms.positions",
#         "run.system.atoms.species",
#         "run.system.chemical_composition",
#         "run.system.chemical_composition_hill",
#         "run.system.chemical_composition_reduced",
#         "run.system.configuration_raw_gid",
#         "run.system.is_representative",
#         "run.system.prototype",
#         "run.system.prototype.aflow_id",
#         "run.system.prototype.aflow_url",
#         "run.system.prototype.assignment_method",
#         "run.system.prototype.label",
#         "run.system.symmetry",
#         "run.system.symmetry.bravais_lattice",
#         "run.system.symmetry.crystal_system",
#         "run.system.symmetry.hall_number",
#         "run.system.symmetry.hall_symbol",
#         "run.system.symmetry.international_short_symbol",
#         "run.system.symmetry.origin_shift",
#         "run.system.symmetry.point_group",
#         "run.system.symmetry.space_group_number",
#         "run.system.symmetry.symmetry_method",
#         "run.system.symmetry.system_original",
#         "run.system.symmetry.system_original.equivalent_atoms",
#         "run.system.symmetry.system_original.wyckoff_letters",
#         "run.system.symmetry.system_primitive",
#         "run.system.symmetry.system_primitive.atomic_numbers",
#         "run.system.symmetry.system_primitive.equivalent_atoms",
#         "run.system.symmetry.system_primitive.lattice_vectors",
#         "run.system.symmetry.system_primitive.positions",
#         "run.system.symmetry.system_primitive.wyckoff_letters",
#         "run.system.symmetry.system_std",
#         "run.system.symmetry.system_std.atomic_numbers",
#         "run.system.symmetry.system_std.equivalent_atoms",
#         "run.system.symmetry.system_std.lattice_vectors",
#         "run.system.symmetry.system_std.positions",
#         "run.system.symmetry.system_std.wyckoff_letters",
#         "run.system.symmetry.transformation_matrix",
#         "run.system.type",
#         "workflow",
#         "workflow.calculation_result_ref",
#         "workflow.calculations_ref",
#         "workflow.single_point",
#         "workflow.single_point.final_scf_energy_difference",
#         "workflow.single_point.is_converged",
#         "workflow.single_point.method",
#         "workflow.single_point.n_scf_steps",
#         "workflow.single_point.with_bandstructure",
#         "workflow.single_point.with_density_of_states",
#         "workflow.single_point.with_eigenvalues",
#         "workflow.single_point.with_excited_states",
#         "workflow.single_point.with_volumetric_data",
#         "workflow.task",
#         "workflow.task.input_calculation",
#         "workflow.task.input_workflow",
#         "workflow.task.output_calculation",
#         "workflow.task.output_workflow",
#         "workflow.type"
#       ],
#       "pid": "1737270",
#       "datasets": [],
#       "n_quantities": 467,
#       "nomad_version": "1.0.0",
#       "upload_create_time": "2015-05-26T21:57:41.260000",
#       "nomad_commit": "f0ee3d31",
#       "publish_time": "2015-05-26T21:57:41.260000",
#       "processing_errors": [],
#       "results": {
#         "material": {
#           "symmetry": {
#             "bravais_lattice": "cF",
#             "space_group_symbol": "Fm-3m",
#             "prototype_aflow_id": "AB2C_cF16_225_a_c_b",
#             "structure_name": "Heusler",
#             "strukturbericht_designation": "L21",
#             "prototype_formula": "AlCu2Mn",
#             "space_group_number": 225,
#             "point_group": "m-3m",
#             "crystal_system": "cubic",
#             "hall_number": 523,
#             "hall_symbol": "-F 4 2 3"
#           },
#           "elements": [
#             "Co",
#             "Cu",
#             "Ni"
#           ],
#           "elements_exclusive": "Co Cu Ni",
#           "chemical_formula_anonymous": "A2BC",
#           "material_id": "UrBvfAOr_nkSnD6LH4vsOcqwc8zL",
#           "structural_type": "bulk",
#           "chemical_formula_reduced": "Co2CuNi",
#           "n_elements": 3,
#           "chemical_formula_descriptive": "Co2CuNi",
#           "chemical_formula_reduced_fragments": [
#             "Co2",
#             "Cu",
#             "Ni"
#           ],
#           "chemical_formula_hill": "Co2CuNi"
#         },
#         "method": {
#           "method_name": "DFT",
#           "simulation": {
#             "program_version": "4.6.35 3Apr08 complex parallel LinuxIFC",
#             "dft": {
#               "basis_set_type": "plane waves",
#               "core_electron_treatment": "pseudopotential",
#               "xc_functional_type": "GGA",
#               "xc_functional_names": [
#                 "GGA_C_PBE",
#                 "GGA_X_PBE"
#               ],
#               "scf_threshold_energy_change": 1.602176634e-25
#             },
#             "program_name": "VASP"
#           }
#         },
#         "properties": {
#           "available_properties": [
#             "band_gap",
#             "band_structure_electronic",
#             "electronic",
#             "electronic.band_structure_electronic",
#             "electronic.band_structure_electronic.band_gap",
#             "electronic.band_structure_electronic.band_gap.energy_highest_occupied",
#             "electronic.band_structure_electronic.band_gap.energy_lowest_unoccupied",
#             "electronic.band_structure_electronic.band_gap.index",
#             "electronic.band_structure_electronic.band_gap.value",
#             "electronic.band_structure_electronic.reciprocal_cell",
#             "electronic.band_structure_electronic.segment",
#             "electronic.band_structure_electronic.spin_polarized",
#             "element",
#             "energy_highest_occupied",
#             "energy_lowest_unoccupied",
#             "index",
#             "indices",
#             "n_calculations",
#             "reciprocal_cell",
#             "segment",
#             "spin_polarized",
#             "structure_conventional",
#             "structure_original",
#             "structure_primitive",
#             "structures",
#             "structures.structure_conventional",
#             "structures.structure_conventional.atomic_density",
#             "structures.structure_conventional.cartesian_site_positions",
#             "structures.structure_conventional.cell_volume",
#             "structures.structure_conventional.dimension_types",
#             "structures.structure_conventional.lattice_parameters",
#             "structures.structure_conventional.lattice_parameters.a",
#             "structures.structure_conventional.lattice_parameters.alpha",
#             "structures.structure_conventional.lattice_parameters.b",
#             "structures.structure_conventional.lattice_parameters.beta",
#             "structures.structure_conventional.lattice_parameters.c",
#             "structures.structure_conventional.lattice_parameters.gamma",
#             "structures.structure_conventional.lattice_vectors",
#             "structures.structure_conventional.mass_density",
# ...
#           "chemical_formula_reduced_fragments": [
#             "Cu",
#             "Ni6",
#             "Ta"
#           ],
#           "chemical_formula_hill": "Cu4Ni24Ta4"
#         },
#         "method": {
#           "method_name": "DFT",
#           "simulation": {
#             "program_version": "4.6.35 3Apr08 complex parallel LinuxIFC",
#             "dft": {
#               "basis_set_type": "plane waves",
#               "core_electron_treatment": "pseudopotential",
#               "xc_functional_type": "GGA",
#               "xc_functional_names": [
#                 "GGA_C_PBE",
#                 "GGA_X_PBE"
#               ],
#               "scf_threshold_energy_change": 1.602176634e-23
#             },
#             "program_name": "VASP"
#           }
#         },
#         "properties": {
#           "available_properties": [
#             "band_structure_electronic",
#             "electronic.band_structure_electronic.band_gap"
#           ],
#           "n_calculations": 1,
#           "structures": {
#             "structure_primitive": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 32,
#               "cell_volume": 3.738476848991777e-28,
#               "lattice_parameters": {
#                 "a": 6.237327880514616e-10,
#                 "b": 6.237327880514616e-10,
#                 "c": 1.0201304730000003e-09,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.913110746800968
#               }
#             },
#             "structure_conventional": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 64,
#               "cell_volume": 7.476953697983567e-28,
#               "lattice_parameters": {
#                 "a": 7.189622980000001e-10,
#                 "b": 1.019442778e-09,
#                 "c": 1.0201304730000003e-09,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.5707963267948966
#               }
#             },
#             "structure_original": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 32,
#               "cell_volume": 3.738476848991777e-28,
#               "lattice_parameters": {
#                 "a": 6.237327880514616e-10,
#                 "b": 6.237327880514616e-10,
#                 "c": 1.0201304730000003e-09,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.913110746800968
#               }
#             }
#           },
#           "electronic": {
#             "band_structure_electronic": {
#               "spin_polarized": true,
#               "band_gap": [
#                 {
#                   "index": 0,
#                   "value": 0.0
#                 },
#                 {
#                   "index": 1,
#                   "value": 0.0
#                 }
#               ]
#             }
#           }
#         }
#       },
#       "last_processing_time": "2021-12-26T23:23:57.754000",
#       "optimade": {
#         "nperiodic_dimensions": 3,
#         "species_at_sites": [
#           "Cu",
#           "Cu",
#           "Cu",
#           "Cu",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ni",
#           "Ta",
#           "Ta",
#           "Ta",
#           "Ta"
#         ],
#         "nsites": 32,
#         "elements": [
#           "Cu",
#           "Ni",
#           "Ta"
#         ],
#         "chemical_formula_anonymous": "A24B4C4",
#         "chemical_formula_reduced": "Cu4Ni24Ta4",
#         "structure_features": [],
#         "nelements": 3,
#         "chemical_formula_descriptive": "Cu4Ni24Ta4",
#         "chemical_formula_hill": "Cu4Ni24Ta4",
#         "elements_ratios": [
#           [
#             {
#               "elements": "Cu",
#               "elements_ratios": 0.125
#             },
#             {
#               "elements": "Ni",
#               "elements_ratios": 0.75
#             },
#             {
#               "elements": "Ta",
#               "elements_ratios": 0.125
#             }
#           ],
#           [
#             {
#               "elements": "Cu",
#               "elements_ratios": 0.125
#             },
#             {
#               "elements": "Ni",
#               "elements_ratios": 0.75
#             },
#             {
#               "elements": "Ta",
#               "elements_ratios": 0.125
#             }
#           ],
#           [
#             {
#               "elements": "Cu",
#               "elements_ratios": 0.125
#             },
#             {
#               "elements": "Ni",
#               "elements_ratios": 0.75
#             },
#             {
#               "elements": "Ta",
#               "elements_ratios": 0.125
#             }
#           ]
#         ]
#       },
#       "parser_name": "parsers/vasp",
#       "calc_id": "-ldqK9wLvTx97YriYbnSMFd7DtCf",
#       "published": true,
#       "writers": [
#         {
#           "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#           "name": "Stefano Curtarolo"
#         },
#         {
#           "user_id": "f7b540eb-a266-4379-9611-911ed8e3630e",
#           "name": "Wahyu Setyawan"
#         },
#         {
#           "user_id": "d2621bc7-c45a-4d35-9dc1-5c05fa8326cb",
#           "name": "Frisco Rose"
#         },
#         {
#           "user_id": "9c308f66-eed1-4996-b33e-af78fb4944c7",
#           "name": "Richard Taylor"
#         },
#         {
#           "user_id": "d63d07e6-ccc8-4eac-82af-d841627b6c53",
#           "name": "Ohad Levy"
#         },
#         {
#           "user_id": "48e7a028-1a41-440d-9986-38540f5079c9",
#           "name": "Cormac Toher"
#         },
#         {
#           "user_id": "7b3fe468-0011-4ba8-bd53-1ee65acda114",
#           "name": "Marco Buongiorno Nardelli"
#         },
#         {
#           "user_id": "3df68fed-6ca0-4bf9-b2b1-d6be71e18f72",
#           "name": "Shidong Wang"
#         },
#         {
#           "user_id": "ecba0e68-65ee-4b40-8fbf-a42714b1072b",
#           "name": "Junkai Xue"
#         },
#         {
#           "user_id": "f409d859-2639-4f82-b198-85e1c7c62f8b",
#           "name": "Kesong Yang"
#         },
#         {
#           "user_id": "580f7036-97b8-42b1-a9e6-815058bcac72",
#           "name": "Lance Nelson"
#         },
#         {
#           "user_id": "4c8d767d-335f-4ccd-9459-d0152b2026bc",
#           "name": "Gus Hart"
#         },
#         {
#           "user_id": "7effd16a-a65c-4d95-b692-652488d94146",
#           "name": "Stefano Sanvito"
#         },
#         {
#           "user_id": "d59b3610-6335-4ad8-aca0-24a905de3a25",
#           "name": "Natalio Mingo"
#         }
#       ],
#       "processed": true,
#       "mainfile": "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasprun.xml.bands",
#       "main_author": {
#         "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#         "name": "Stefano Curtarolo"
#       },
#       "viewers": [
#         {
#           "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#           "name": "Stefano Curtarolo"
#         },
#         {
#           "user_id": "f7b540eb-a266-4379-9611-911ed8e3630e",
#           "name": "Wahyu Setyawan"
#         },
#         {
#           "user_id": "d2621bc7-c45a-4d35-9dc1-5c05fa8326cb",
#           "name": "Frisco Rose"
#         },
#         {
#           "user_id": "9c308f66-eed1-4996-b33e-af78fb4944c7",
#           "name": "Richard Taylor"
#         },
#         {
#           "user_id": "d63d07e6-ccc8-4eac-82af-d841627b6c53",
#           "name": "Ohad Levy"
#         },
#         {
#           "user_id": "48e7a028-1a41-440d-9986-38540f5079c9",
#           "name": "Cormac Toher"
#         },
#         {
#           "user_id": "7b3fe468-0011-4ba8-bd53-1ee65acda114",
#           "name": "Marco Buongiorno Nardelli"
#         },
#         {
#           "user_id": "3df68fed-6ca0-4bf9-b2b1-d6be71e18f72",
#           "name": "Shidong Wang"
#         },
#         {
#           "user_id": "ecba0e68-65ee-4b40-8fbf-a42714b1072b",
#           "name": "Junkai Xue"
#         },
#         {
#           "user_id": "f409d859-2639-4f82-b198-85e1c7c62f8b",
#           "name": "Kesong Yang"
#         },
#         {
#           "user_id": "580f7036-97b8-42b1-a9e6-815058bcac72",
#           "name": "Lance Nelson"
#         },
#         {
#           "user_id": "4c8d767d-335f-4ccd-9459-d0152b2026bc",
#           "name": "Gus Hart"
#         },
#         {
#           "user_id": "7effd16a-a65c-4d95-b692-652488d94146",
#           "name": "Stefano Sanvito"
#         },
#         {
#           "user_id": "d59b3610-6335-4ad8-aca0-24a905de3a25",
#           "name": "Natalio Mingo"
#         }
#       ],
#       "entry_create_time": "2019-07-20T01:45:26",
#       "with_embargo": false,
#       "external_db": "AFLOW",
#       "domain": "dft",
#       "files": [
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasprun.xml.bands",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/AECCAR0.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/AECCAR2.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/CHG.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/CHGCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/CONTCAR.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/CONTCAR.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/CONTCAR.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/CONTCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/DOSCAR.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/DOSCAR.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/DOSCAR.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/DOSCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/EIGENVAL.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/EIGENVAL.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/EIGENVAL.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/EIGENVAL.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/IBZKPT.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/IBZKPT.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/IBZKPT.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/INCAR.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/INCAR.orig.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/INCAR.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/INCAR.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/INCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/KPOINTS.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/KPOINTS.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/KPOINTS.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/KPOINTS.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/LOCK",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/LOCK.30984",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OSZICAR.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OSZICAR.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OSZICAR.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OSZICAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OUTCAR.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OUTCAR.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OUTCAR.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/OUTCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/PCDAT.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/PCDAT.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/PCDAT.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/PCDAT.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/POSCAR.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/POSCAR.orig.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/POSCAR.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/POSCAR.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/POSCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/PROCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/XDATCAR.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/XDATCAR.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/XDATCAR.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/XDATCAR.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.agroup.out.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.end.out",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.error.nbands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.error.out.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.fgroup.out.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.iatoms.out.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.in",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.pgroup.out.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.pgroup_xtal.out.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/aflow.qmvasp.out.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasp.out.bands.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasp.out.relax1.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasp.out.relax2.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasp.out.static.bz2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasprun.xml.relax1",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasprun.xml.relax2",
#         "aflowlib_data/LIB3_LIB/Cu_pvNi_pvTa_pv/TS001.CAB/vasprun.xml.static"
#       ],
#       "entry_id": "-ldqK9wLvTx97YriYbnSMFd7DtCf",
#       "upload_name": "fs7X5FV6Qz6KdqPPX1BVvA",
#       "authors": [
#         {
#           "user_id": "81b96683-7170-49d7-8c4e-e9f34906b3ea",
#           "name": "Stefano Curtarolo"
#         },
#         {
#           "user_id": "f7b540eb-a266-4379-9611-911ed8e3630e",
#           "name": "Wahyu Setyawan"
#         },
#         {
#           "user_id": "d2621bc7-c45a-4d35-9dc1-5c05fa8326cb",
#           "name": "Frisco Rose"
#         },
#         {
#           "user_id": "9c308f66-eed1-4996-b33e-af78fb4944c7",
#           "name": "Richard Taylor"
#         },
#         {
#           "user_id": "d63d07e6-ccc8-4eac-82af-d841627b6c53",
#           "name": "Ohad Levy"
#         },
#         {
#           "user_id": "48e7a028-1a41-440d-9986-38540f5079c9",
#           "name": "Cormac Toher"
#         },
#         {
#           "user_id": "7b3fe468-0011-4ba8-bd53-1ee65acda114",
#           "name": "Marco Buongiorno Nardelli"
#         },
#         {
#           "user_id": "3df68fed-6ca0-4bf9-b2b1-d6be71e18f72",
#           "name": "Shidong Wang"
#         },
#         {
#           "user_id": "ecba0e68-65ee-4b40-8fbf-a42714b1072b",
#           "name": "Junkai Xue"
#         },
#         {
#           "user_id": "f409d859-2639-4f82-b198-85e1c7c62f8b",
#           "name": "Kesong Yang"
#         },
#         {
#           "user_id": "580f7036-97b8-42b1-a9e6-815058bcac72",
#           "name": "Lance Nelson"
#         },
#         {
#           "user_id": "4c8d767d-335f-4ccd-9459-d0152b2026bc",
#           "name": "Gus Hart"
#         },
#         {
#           "user_id": "7effd16a-a65c-4d95-b692-652488d94146",
#           "name": "Stefano Sanvito"
#         },
#         {
#           "user_id": "d59b3610-6335-4ad8-aca0-24a905de3a25",
#           "name": "Natalio Mingo"
#         }
#       ],
#       "license": "CC BY 4.0"
#     }
#   ]
# }

# %%
print(response_json['data'][0]['entry_id'])
# Out:
# --68O6KEt0GF5R9scUaiEpcvbXiG

# %%
first_entry_id = response_json['data'][0]['entry_id']
response = requests.post(
    f'{base_url}/entries/{first_entry_id}/archive/query',
    json={
        'required': {
            'workflow': {
                'calculation_result_ref': {
                    'energy': '*',
                    'system_ref': {
                        'chemical_composition': '*'
                    }
                }
            }
        }
    })
response_json = response.json()
print(json.dumps(response_json, indent=2))
# Out:
# {
#   "entry_id": "--68O6KEt0GF5R9scUaiEpcvbXiG",
#   "required": {
#     "workflow": {
#       "calculation_result_ref": {
#         "energy": "*",
#         "system_ref": {
#           "chemical_composition": "*"
#         }
#       }
#     }
#   },
#   "data": {
#     "entry_id": "--68O6KEt0GF5R9scUaiEpcvbXiG",
#     "upload_id": "GaUS1MToTwaP60R_e-vIDQ",
#     "parser_name": "parsers/vasp",
#     "archive": {
#       "m_ref_archives": {}
#     }
#   }
# }

# %%
response = requests.post(
    f'{base_url}/entries/query',
    json={
        'query': {
            "results.properties.electronic.band_structure_electronic.band_gap": {
              "type:any": [
                "direct"
              ],
              "value": {
                "gte": 4.085759767784399e-19,
                "lte": 2.3134258869804897e-18
              }
            }
        },
        'pagination': {
            'page_size': 5
        },
        'required': {
            "results": {
                "material": {
                    "chemical_formula_reduced": "*"
                }
            }
        }
    })

response_json = response.json()

#print(json.dumps(response.json(), indent=2))
for entry in response_json['data']:
    print(entry['entry_id'])
    print(entry['results']['material']['chemical_formula_reduced'])
# Out:
# --0ttXeSYjWlLRMm2OIrzujNOxCb
# H4Li4
# --7EO2Q1exqlLBm9dImG4WKJybsk
# ClLi
# --Hz0U6YpO691ha6_CatQ0KrhOjJ
# Ca4O4
# --_npCChxBlIE3bkLaawtkngnEkS
# ClCs
# --b--AqROml19cw86rZ748lzPkQY
# ClCs

# %%
response = requests.post(
    f'{base_url}/entries/query',
    json={
  "query": {
    "results.properties.available_properties:all": [
      "dos_electronic"
    ],
    "results.material.elements:all": [
      "Zn",
      "N"
    ]
  }
    })

response_json = response.json()

#print(json.dumps(response.json(), indent=2))
for entry in response_json['data']:
    print(entry['entry_id'])
    print(entry['results']['material']['chemical_formula_reduced'])
# Out:
# --0rqGz0nrAgdJ4czSZj3z7RhfUo
# C30H22N4O10Zn2
# --Wz6tgUwTf42VOFywLoaxjRqmz_
# C2H5N4O3PZn
# --p1ZMM7dHfAuverhpUZj6pnsU43
# C30H28NO7SZn
# --qHZ_w9rt8j6oA9OtwTjnqztlYC
# C20H16N2O5Zn
# -0Nkx5F68kBZHlPkn7wHqdWTITl-
# C22H18N4O4Zn
# -0saIPrO5wvjVbmO50E18ivW-6nf
# C4H20N16O12S4Zn2
# -0vwPEkVEHdxNuZqG5bdSFNVcg6v
# C12H12N16O8Zn2
# -1FA7agiAG8c9YcK2Ja7MB9_82HN
# HfN2Zn
# -1_kXlSjAmOZhh98svd_EQB-MgvN
# C4H16N18O7Zn2
# -1s4zUNrfzTuGO6Si_iTA6UwDlEz
# C4H9N9O4S4Zn

# %%
for entry in response_json['data']:
    print(entry['entry_id'])
    print(entry['results']['properties']['electronic'])
# Out:
# --0rqGz0nrAgdJ4czSZj3z7RhfUo
# {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}
# --Wz6tgUwTf42VOFywLoaxjRqmz_
# {'dos_electronic': [{'spin_polarized': False, 'band_gap': [{'index': 0, 'value': 7.2911854260072e-19}]}], 'band_gap': [{'provenance': {'label': 'dos'}, 'index': 0, 'value': 7.2911854260072e-19}]}
# --p1ZMM7dHfAuverhpUZj6pnsU43
# {'dos_electronic': [{'spin_polarized': False}], 'band_gap': [{'value': 2.981782075420252e-19}]}
# --qHZ_w9rt8j6oA9OtwTjnqztlYC
# {'dos_electronic': [{'spin_polarized': False}], 'band_gap': [{'value': 5.461560116618974e-19}]}
# -0Nkx5F68kBZHlPkn7wHqdWTITl-
# {'dos_electronic': [], 'dos_electronic_new': [{'has_projected': False, 'data': [], 'spin_polarized': False}], 'band_gap': [{'value': 5.847802273517982e-19}]}
# -0saIPrO5wvjVbmO50E18ivW-6nf
# {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}
# -0vwPEkVEHdxNuZqG5bdSFNVcg6v
# {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}
# -1FA7agiAG8c9YcK2Ja7MB9_82HN
# {'dos_electronic': [{'spin_polarized': True, 'band_gap': [{'index': 0, 'value': 3.291671894552999e-19}, {'index': 1, 'value': 3.291671894552999e-19}]}], 'band_gap': [{'provenance': {'label': 'dos'}, 'index': 0, 'value': 3.291671894552999e-19}, {'provenance': {'label': 'dos'}, 'index': 1, 'value': 3.291671894552999e-19}]}
# -1_kXlSjAmOZhh98svd_EQB-MgvN
# {'dos_electronic': [{'spin_polarized': True, 'band_gap': [{'index': 0, 'value': 6.047575922696399e-19}, {'index': 1, 'value': 6.047575922696399e-19}]}], 'band_gap': [{'provenance': {'label': 'dos'}, 'index': 0, 'value': 6.047575922696399e-19}, {'provenance': {'label': 'dos'}, 'index': 1, 'value': 6.047575922696399e-19}]}
# -1s4zUNrfzTuGO6Si_iTA6UwDlEz
# {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}

# %%
for entry in response_json['data']:
    print(entry['entry_id'])
    print(entry['results']['properties'])
# Out:
# --0rqGz0nrAgdJ4czSZj3z7RhfUo
# {'available_properties': ['dos_electronic'], 'n_calculations': 1, 'structures': {'structure_original': {'nperiodic_dimensions': 3, 'n_sites': 68, 'cell_volume': 6.6733953662880805e-28, 'lattice_parameters': {'a': 7.688073453049665e-10, 'b': 8.844780734104211e-10, 'c': 1.075680923639325e-09, 'alpha': 1.3986267455021546, 'beta': 1.2158937080749928, 'gamma': 1.364665458968014}}}, 'electronic': {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}}
# --Wz6tgUwTf42VOFywLoaxjRqmz_
# {'available_properties': ['dos_electronic'], 'n_calculations': 1, 'electronic': {'dos_electronic': [{'spin_polarized': False, 'band_gap': [{'index': 0, 'value': 7.2911854260072e-19}]}], 'band_gap': [{'provenance': {'label': 'dos'}, 'index': 0, 'value': 7.2911854260072e-19}]}}
# --p1ZMM7dHfAuverhpUZj6pnsU43
# {'available_properties': ['dos_electronic', 'geometry_optimization'], 'n_calculations': 37, 'electronic': {'dos_electronic': [{'spin_polarized': False}], 'band_gap': [{'value': 2.981782075420252e-19}]}, 'mechanical': {}, 'geometry_optimization': {'final_force_maximum': 2.4038112191377952e-11, 'final_energy_difference': 7.036424467746934e-23}}
# --qHZ_w9rt8j6oA9OtwTjnqztlYC
# {'available_properties': ['dos_electronic', 'geometry_optimization'], 'n_calculations': 27, 'electronic': {'dos_electronic': [{'spin_polarized': False}], 'band_gap': [{'value': 5.461560116618974e-19}]}, 'mechanical': {}, 'geometry_optimization': {'final_force_maximum': 3.8912482500352695e-11, 'final_energy_difference': 6.097332102874727e-23}}
# -0Nkx5F68kBZHlPkn7wHqdWTITl-
# {'available_properties': ['dos_electronic', 'dos_electronic_new', 'geometry_optimization'], 'n_calculations': 24, 'electronic': {'dos_electronic': [], 'dos_electronic_new': [{'has_projected': False, 'data': [], 'spin_polarized': False}], 'band_gap': [{'value': 5.847802273517982e-19}]}, 'mechanical': {}, 'geometry_optimization': {'final_force_maximum': 2.8419856869332607e-11, 'final_energy_difference': 2.7181963818576094e-23}}
# -0saIPrO5wvjVbmO50E18ivW-6nf
# {'available_properties': ['dos_electronic'], 'n_calculations': 1, 'structures': {'structure_primitive': {'nperiodic_dimensions': 3, 'n_sites': 58, 'cell_volume': 5.427975297394927e-28, 'lattice_parameters': {'a': 6.467612083632336e-10, 'b': 6.467612083632336e-10, 'c': 1.412788374081738e-09, 'alpha': 1.735611915933045, 'beta': 1.735611915933045, 'gamma': 1.2150674045573817}}, 'structure_conventional': {'nperiodic_dimensions': 3, 'n_sites': 116, 'cell_volume': 1.0855950594789873e-27, 'lattice_parameters': {'a': 1.0620574268531058e-09, 'b': 7.383998e-10, 'c': 1.412788374081738e-09, 'alpha': 1.5707963267948966, 'beta': 1.7719786628429652, 'gamma': 1.5707963267948966}}, 'structure_original': {'nperiodic_dimensions': 3, 'n_sites': 58, 'cell_volume': 5.427975297394927e-28, 'lattice_parameters': {'a': 6.467612083632335e-10, 'b': 6.467612083632335e-10, 'c': 1.4127883740817378e-09, 'alpha': 1.735611915933045, 'beta': 1.735611915933045, 'gamma': 1.2150674045573815}}}, 'electronic': {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}}
# -0vwPEkVEHdxNuZqG5bdSFNVcg6v
# {'available_properties': ['dos_electronic'], 'n_calculations': 1, 'structures': {'structure_primitive': {'nperiodic_dimensions': 3, 'n_sites': 50, 'cell_volume': 5.062627743804376e-28, 'lattice_parameters': {'a': 8.330429244129275e-10, 'b': 8.330429244129275e-10, 'c': 9.580313887376449e-10, 'alpha': 1.995048484933913, 'beta': 1.995048484933913, 'gamma': 1.0459881923115908}}, 'structure_conventional': {'nperiodic_dimensions': 3, 'n_sites': 100, 'cell_volume': 1.0125255487608772e-27, 'lattice_parameters': {'a': 1.4433761300853954e-09, 'b': 8.321702967286673e-10, 'c': 9.580313887376449e-10, 'alpha': 1.5707963267948966, 'beta': 2.0659358106558643, 'gamma': 1.5707963267948966}}, 'structure_original': {'nperiodic_dimensions': 3, 'n_sites': 50, 'cell_volume': 5.0626277437912105e-28, 'lattice_parameters': {'a': 8.330434808944103e-10, 'b': 8.330423679310733e-10, 'c': 9.580313887376447e-10, 'alpha': 1.146543460961223, 'beta': 1.1465448763491646, 'gamma': 1.0459881923110739}}}, 'electronic': {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}}
# -1FA7agiAG8c9YcK2Ja7MB9_82HN
# {'available_properties': ['dos_electronic'], 'n_calculations': 1, 'electronic': {'dos_electronic': [{'spin_polarized': True, 'band_gap': [{'index': 0, 'value': 3.291671894552999e-19}, {'index': 1, 'value': 3.291671894552999e-19}]}], 'band_gap': [{'provenance': {'label': 'dos'}, 'index': 0, 'value': 3.291671894552999e-19}, {'provenance': {'label': 'dos'}, 'index': 1, 'value': 3.291671894552999e-19}]}}
# -1_kXlSjAmOZhh98svd_EQB-MgvN
# {'available_properties': ['dos_electronic', 'geometry_optimization'], 'n_calculations': 26, 'electronic': {'dos_electronic': [{'spin_polarized': True, 'band_gap': [{'index': 0, 'value': 6.047575922696399e-19}, {'index': 1, 'value': 6.047575922696399e-19}]}], 'band_gap': [{'provenance': {'label': 'dos'}, 'index': 0, 'value': 6.047575922696399e-19}, {'provenance': {'label': 'dos'}, 'index': 1, 'value': 6.047575922696399e-19}]}, 'mechanical': {}, 'geometry_optimization': {'convergence_tolerance_energy_difference': 1.50604603596e-20, 'final_displacement_maximum': 7.690489288775129e-13, 'final_force_maximum': 3.645491935256556e-10, 'final_energy_difference': 1.1613040874472479e-21}}
# -1s4zUNrfzTuGO6Si_iTA6UwDlEz
# {'available_properties': ['dos_electronic'], 'n_calculations': 1, 'structures': {'structure_primitive': {'nperiodic_dimensions': 3, 'n_sites': 31, 'cell_volume': 3.6685171747044397e-28, 'lattice_parameters': {'a': 7.669002959097877e-10, 'b': 7.722503126417601e-10, 'c': 7.929428719469211e-10, 'alpha': 1.5679650509575547, 'beta': 1.082118333955768, 'gamma': 1.1452035398485907}}, 'structure_conventional': {'nperiodic_dimensions': 3, 'n_sites': 31, 'cell_volume': 3.6685171747044397e-28, 'lattice_parameters': {'a': 7.669002959097877e-10, 'b': 7.722503126417601e-10, 'c': 7.929428719469211e-10, 'alpha': 1.5679650509575547, 'beta': 1.082118333955768, 'gamma': 1.1452035398485907}}, 'structure_original': {'nperiodic_dimensions': 3, 'n_sites': 31, 'cell_volume': 3.6685171747044397e-28, 'lattice_parameters': {'a': 7.669002959097877e-10, 'b': 7.722503126417601e-10, 'c': 7.929428719469212e-10, 'alpha': 1.5679650509575547, 'beta': 1.082118333955768, 'gamma': 1.1452035398485907}}}, 'electronic': {'dos_electronic': {'spin_polarized': False, 'band_gap': [{'index': 0}]}}}

# %%
response = requests.post(
    f'{base_url}/entries/query',
    json={
  "query": {
    "results.properties.available_properties:all": [
      "dos_electronic"
    ],
    "results.material.elements:all": [
      "Zn",
      "N"
    ]
  },
        'pagination': {
            'page_size': 20
        }
    })

response_json = response.json()

#print(json.dumps(response.json(), indent=2))
for entry in response_json['data']:
    print(entry['entry_id'])
    print(entry['results']['material']['chemical_formula_reduced'])
# Out:
# --0rqGz0nrAgdJ4czSZj3z7RhfUo
# C30H22N4O10Zn2
# --Wz6tgUwTf42VOFywLoaxjRqmz_
# C2H5N4O3PZn
# --p1ZMM7dHfAuverhpUZj6pnsU43
# C30H28NO7SZn
# --qHZ_w9rt8j6oA9OtwTjnqztlYC
# C20H16N2O5Zn
# -0Nkx5F68kBZHlPkn7wHqdWTITl-
# C22H18N4O4Zn
# -0saIPrO5wvjVbmO50E18ivW-6nf
# C4H20N16O12S4Zn2
# -0vwPEkVEHdxNuZqG5bdSFNVcg6v
# C12H12N16O8Zn2
# -1FA7agiAG8c9YcK2Ja7MB9_82HN
# HfN2Zn
# -1_kXlSjAmOZhh98svd_EQB-MgvN
# C4H16N18O7Zn2
# -1s4zUNrfzTuGO6Si_iTA6UwDlEz
# C4H9N9O4S4Zn
# -2-yaIjaEOYIFtqifZKOlbMdQem2
# C44H36N20O24Zn4
# -2jHe2jvoi9580cEOkJC_lXu53h2
# C56H36N4O28Zn4
# -3EwGN6mbpo6_aYM0jw6z27VC0ph
# C24H18N2O4S2Zn
# -3vsnMjH29TV5UcrITiJOn77meyy
# C13H16N2O6P2Zn2
# -3z9XxJBeiTq-HFwBeRMRATWSY8w
# C44H36N8O8Zn2
# -4hlwYec5cdldVjqeM4eoOcy8s7Y
# N3ReZn
# -50J7ds7G1GDwsdrXhMq3o4yQgYY
# C10H12N4Zn
# -5H_uvYRuWLrGq8_rvkCWKYDCVmS
# C29H21N5O4Zn
# -5dFzdK36Vgm5EqXQw65-lpHTQTa
# N2O6Zn
# -5dzMshK5wvzQUm8ohMiXKZmpZtA
# C48H34N6O8Zn2
